# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
import math, time, copy

import utils, parameters, Unet_models
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "3"
dir_name        = "20220901_bgerr" + str(parameters.background_err)
print(dir_name)
# Out:
# 20220828_bgerr0.0

# %%
training_set_npz = np.load('dataset/N' + str(parameters.sigNoise) + '_training_set.npz')
x_train_obs = training_set_npz['x_train_obs']
x_train = training_set_npz['x_train']
mask_train = training_set_npz['mask_train']

x_val_obs = training_set_npz['x_val_obs']
x_val = training_set_npz['x_val']
mask_val = training_set_npz['mask_val']

stdTr = training_set_npz['std']
meanTr = training_set_npz['mean']

# %%
batchsize = 32

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

training_dataset  = torch.utils.data.TensorDataset(torch.Tensor(x_train_obs), torch.Tensor(x_train), torch.Tensor(mask_train))
val_dataset       = torch.utils.data.TensorDataset(torch.Tensor(x_val_obs),  torch.Tensor(x_val), torch.Tensor(mask_val)) 

dataloaders = {
    'train': torch.utils.data.DataLoader(training_dataset, batch_size=batchsize, shuffle=True, num_workers=4, pin_memory=True),
    'val': torch.utils.data.DataLoader(val_dataset, batch_size=batchsize, shuffle=True, num_workers=4, pin_memory=True),
}

dataset_sizes = {'train': len(training_dataset), 'val': len(val_dataset)}

# %%
model_head  = Unet_models.L96_UnetConvRec_head().to(device)
model_dyn   = Unet_models.L96_UnetConvRec_dyn().to(device)
model_sup   = Unet_models.L96_UnetConvRec_sup().to(device)

model_head.load_state_dict(torch.load("ckpts/" + dir_name + "/pretrain_head_epoch20"))
model_dyn.load_state_dict(torch.load("ckpts/" + dir_name + "/pretrain_dyn_epoch200"))

best_model_dyn_wts  = copy.deepcopy(model_dyn.state_dict())

# %%
num_epochs_sup  = [   10,   10,   10]
num_epochs_dyn  = [   10,   10,   10]
lr_head         = [ 1e-4,    0,    0]
# lr_head         = [    0,    0,    0]
lr_sup          = [ 1e-4, 1e-4, 1e-4]
lr_dyn          = [ 1e-4, 1e-4, 1e-4]
num_epochs_list = [num_epochs_sup, num_epochs_dyn]
mod_name        = ["sup", "dyn"]

if not os.path.exists("ckpts/" + dir_name):
    os.makedirs("ckpts/" + dir_name)
    print("creating dir: ckpts/" + dir_name )
    
if not os.path.exists("train_loss/" + dir_name):
    os.makedirs("train_loss/" + dir_name)
    print("creating dir: train_loss/" + dir_name )

for step in range(1, 4):

    print("step: ", step)
    model = Unet_models.L96_DARNN(model_head, model_dyn, model_sup, step)
    
    for status in range(2): # status=0 -> train sup, status=1 -> train dyn
        
        if status == 0:
            print("finetuning model_sup...")
        else:
            print("finetuning model_dyn...")

        since = time.time()
        best_loss_rec = 1e10

        train_loss_rec_list = []
        val_loss_rec_list = []
        train_loss_dyn_list = []
        val_loss_dyn_list = []
        train_loss_dynbg_list = []
        val_loss_dynbg_list = []
        train_loss_R_list = []
        val_loss_R_list = []
        train_loss_I_list = []
        val_loss_I_list = []
        
        num_epochs = num_epochs_list[status][step-1]
        
        if status == 0:
            model.model_dyn.eval()
            optimizer_model_sup  = optim.Adam(model.model_sup.parameters(),  lr=lr_sup[step-1])
            optimizer_model_head = optim.Adam(model.model_head.parameters(), lr=lr_head[step-1])
            print("optimizing model_sup, lr = ",  lr_sup[step-1])
            print("optimizing model_head, lr = ", lr_head[step-1])
            
        else:
            model.model_sup.eval()
            model.model_head.eval()
            optimizer_model_dyn  = optim.Adam(model.model_dyn.parameters(),  lr=lr_dyn[step-1])
            print("optimizing model_dyn, lr = ",  lr_dyn[step-1])

        for epoch in range(num_epochs):
            print('Epoch {}/{}'.format(epoch, num_epochs - 1))
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    if status == 0:
                        model.model_sup.train()
                        model.model_head.train()
                    else:
                        model.model_dyn.train()
                else:
                    if status == 0:
                        model.model_sup.eval()
                        model.model_head.eval()
                    else:
                        model.model_dyn.eval()

                running_loss_rec    = 0.0
                running_loss_dyn    = 0.0
                running_loss_dyn_bg = 0.0
                running_loss_R      = 0.0
                running_loss_I      = 0.0
                num_loss            = 0

                # Iterate over data.
                for inputs, targets, mask, in dataloaders[phase]:
                    mask        = mask.to(device)
                    targets     = targets.to(device)
                    inputs      = inputs.to(device)
                    
                    if status == 0:
                        optimizer_model_sup.zero_grad()
                        optimizer_model_head.zero_grad()
                    else:
                        optimizer_model_dyn.zero_grad()

                    with torch.set_grad_enabled(True): 
                        outputs    = model(inputs, mask)
                        
                        dyn_list   = torch.zeros(step + 1)
                        dynbg_list = torch.zeros(step + 1)
                        for ii, elem in enumerate(outputs):
                            dyn_list[ii]   = utils.dynamic_loss(elem, 1, meanTr, stdTr, 1)
                            dynbg_list[ii] = utils.dynamic_loss(elem, 1, meanTr, stdTr, 3)
                            
                        output      = outputs[-1]
                        loss_rec    = torch.mean((output - targets)**2)
                        loss_dyn    = dyn_list[-1]
                        loss_dyn_bg = dynbg_list[-1]
                        loss_R      = torch.sum((output - targets)**2 * mask) / torch.sum(mask)
                        loss_I      = torch.sum((output - targets)**2 * (1 - mask)) / torch.sum(1 - mask)
                        
                        if status == 0:
                            loss  = loss_rec
                        else:
                            loss  = loss_rec + 100 * torch.mean(dynbg_list)

                        if phase == 'train':
                            loss.backward()
                            if status == 0:
                                optimizer_model_sup.step()
                                optimizer_model_head.step()
                            else:
                                optimizer_model_dyn.step()

                    running_loss_rec         += loss_rec.item()    * inputs.size(0) * stdTr**2
                    running_loss_dyn         += loss_dyn.item()    * inputs.size(0) * stdTr**2
                    running_loss_dyn_bg      += loss_dyn_bg.item() * inputs.size(0) * stdTr**2
                    running_loss_R           += loss_R.item()      * inputs.size(0) * stdTr**2
                    running_loss_I           += loss_I.item()      * inputs.size(0) * stdTr**2
                    num_loss                 += inputs.size(0)

                epoch_loss_rec       = running_loss_rec    / num_loss
                epoch_loss_dyn       = running_loss_dyn    / num_loss
                epoch_loss_dyn_bg    = running_loss_dyn_bg / num_loss
                epoch_loss_R         = running_loss_R      / num_loss
                epoch_loss_I         = running_loss_I      / num_loss

                print('{} rec loss: {:.4e} dyn loss: {:.4e} dyn loss(bg): {:.4e} loss_R: {:.4e} loss_I: {:.4e}'.format(
                    phase, epoch_loss_rec, epoch_loss_dyn, epoch_loss_dyn_bg, epoch_loss_R, epoch_loss_I))

                if phase == 'train':
                    train_loss_rec_list.append(epoch_loss_rec)
                    train_loss_dyn_list.append(epoch_loss_dyn)
                    train_loss_dynbg_list.append(epoch_loss_dyn_bg)
                    train_loss_R_list.append(epoch_loss_R)
                    train_loss_I_list.append(epoch_loss_I)
                else:
                    val_loss_rec_list.append(epoch_loss_rec)
                    val_loss_dyn_list.append(epoch_loss_dyn)
                    val_loss_dynbg_list.append(epoch_loss_dyn_bg)
                    val_loss_R_list.append(epoch_loss_R)
                    val_loss_I_list.append(epoch_loss_I)

                if phase == 'val' and epoch_loss_rec < best_loss_rec:
                    best_loss_rec = epoch_loss_rec
                    best_model_head_wts = copy.deepcopy(model.model_head.state_dict())
                    best_model_sup_wts  = copy.deepcopy(model.model_sup.state_dict())
                    best_model_dyn_wts  = copy.deepcopy(model.model_dyn.state_dict())

            if epoch_loss_dyn_bg < parameters.relative_err:
                break
                
            print()

        time_elapsed = time.time() - since
        print('Training complete in {:.0f}m {:.0f}s'.format(
            time_elapsed // 60, time_elapsed % 60))
        print('Best val reconstruction loss: {:4e}'.format(best_loss_rec))

        save_dir_model_head = "ckpts/" + dir_name + "/finetune" + str(step*2 + status) + "_head_epoch"  + str(num_epochs)
        save_dir_model_sup  = "ckpts/" + dir_name + "/finetune" + str(step*2 + status) + "_sup_epoch"  + str(num_epochs)
        save_dir_model_dyn  = "ckpts/" + dir_name + "/finetune" + str(step*2 + status) + "_dyn_epoch" + str(num_epochs)
        print("saving model_head at " + save_dir_model_head)
        print("saving model_sup at "  + save_dir_model_sup)
        print("saving model_dyn at "  + save_dir_model_dyn)
        torch.save(best_model_head_wts, save_dir_model_head)
        torch.save(best_model_sup_wts,  save_dir_model_sup)
        torch.save(best_model_dyn_wts,  save_dir_model_dyn)

        save_dir_loss  = "train_loss/" + dir_name + "/finetune" + str(step*2 + status) + "_epoch" + str(num_epochs)
        print("saving loss at " + save_dir_loss)
        np.savez(save_dir_loss,
                 train_loss_rec   = train_loss_rec_list,   val_loss_rec   = val_loss_rec_list, 
                 train_loss_dyn   = train_loss_dyn_list,   val_loss_dyn   = val_loss_dyn_list,
                 train_loss_dynbg = train_loss_dynbg_list, val_loss_dynbg = val_loss_dynbg_list,
                 train_loss_R     = train_loss_R_list,     val_loss_R     = val_loss_R_list, 
                 train_loss_I     = train_loss_I_list,     val_loss_I     = val_loss_I_list,
                 time = time_elapsed)
        
        torch.cuda.empty_cache()
        print()
# Out:
# step:  1
# finetuning model_sup...
# optimizing model_sup, lr =  0.0001
# optimizing model_head, lr =  0.0001
# Epoch 0/9
# ----------
# /software/python/virtualenv/py3.6-gpu/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# train rec loss: 2.0331e+00 dyn loss: 9.8560e-03 dyn loss(bg): 9.8560e-03 loss_R: 1.9318e+00 loss_I: 2.0476e+00
# val rec loss: 5.8775e-01 dyn loss: 1.5539e-03 dyn loss(bg): 1.5539e-03 loss_R: 4.6658e-01 loss_I: 6.0506e-01
#
# Epoch 1/9
# ----------
# train rec loss: 4.5310e-01 dyn loss: 1.1352e-03 dyn loss(bg): 1.1352e-03 loss_R: 3.8010e-01 loss_I: 4.6353e-01
# val rec loss: 5.4351e-01 dyn loss: 1.0971e-03 dyn loss(bg): 1.0971e-03 loss_R: 4.3119e-01 loss_I: 5.5956e-01
#
# Epoch 2/9
# ----------
# train rec loss: 4.2101e-01 dyn loss: 8.8788e-04 dyn loss(bg): 8.8788e-04 loss_R: 3.5451e-01 loss_I: 4.3051e-01
# val rec loss: 5.2691e-01 dyn loss: 9.5209e-04 dyn loss(bg): 9.5209e-04 loss_R: 4.1829e-01 loss_I: 5.4243e-01
#
# Epoch 3/9
# ----------
# train rec loss: 4.0195e-01 dyn loss: 7.7288e-04 dyn loss(bg): 7.7288e-04 loss_R: 3.3915e-01 loss_I: 4.1092e-01
# val rec loss: 5.1151e-01 dyn loss: 8.4729e-04 dyn loss(bg): 8.4729e-04 loss_R: 4.0582e-01 loss_I: 5.2661e-01
#
# Epoch 4/9
# ----------
# train rec loss: 3.8011e-01 dyn loss: 6.5922e-04 dyn loss(bg): 6.5922e-04 loss_R: 3.2177e-01 loss_I: 3.8845e-01
# val rec loss: 4.9082e-01 dyn loss: 7.0124e-04 dyn loss(bg): 7.0124e-04 loss_R: 3.9005e-01 loss_I: 5.0521e-01
#
# Epoch 5/9
# ----------
# train rec loss: 3.5974e-01 dyn loss: 5.5065e-04 dyn loss(bg): 5.5065e-04 loss_R: 3.0593e-01 loss_I: 3.6742e-01
# val rec loss: 4.7711e-01 dyn loss: 6.3591e-04 dyn loss(bg): 6.3591e-04 loss_R: 3.8030e-01 loss_I: 4.9094e-01
#
# Epoch 6/9
# ----------
# train rec loss: 3.5045e-01 dyn loss: 5.0776e-04 dyn loss(bg): 5.0776e-04 loss_R: 2.9850e-01 loss_I: 3.5787e-01
# val rec loss: 4.7596e-01 dyn loss: 5.9886e-04 dyn loss(bg): 5.9886e-04 loss_R: 3.7931e-01 loss_I: 4.8977e-01
#
# Epoch 7/9
# ----------
# train rec loss: 3.4371e-01 dyn loss: 4.8471e-04 dyn loss(bg): 4.8471e-04 loss_R: 2.9324e-01 loss_I: 3.5092e-01
# val rec loss: 4.7279e-01 dyn loss: 5.8511e-04 dyn loss(bg): 5.8511e-04 loss_R: 3.7653e-01 loss_I: 4.8655e-01
#
# Epoch 8/9
# ----------
# train rec loss: 3.3930e-01 dyn loss: 4.7009e-04 dyn loss(bg): 4.7009e-04 loss_R: 2.8983e-01 loss_I: 3.4636e-01
# val rec loss: 4.7542e-01 dyn loss: 5.6641e-04 dyn loss(bg): 5.6641e-04 loss_R: 3.7801e-01 loss_I: 4.8934e-01
#
# Epoch 9/9
# ----------
# train rec loss: 3.3583e-01 dyn loss: 4.6021e-04 dyn loss(bg): 4.6021e-04 loss_R: 2.8720e-01 loss_I: 3.4277e-01
# val rec loss: 4.7213e-01 dyn loss: 5.7911e-04 dyn loss(bg): 5.7911e-04 loss_R: 3.7614e-01 loss_I: 4.8585e-01
#
# Training complete in 4m 45s
# Best val reconstruction loss: 4.721343e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune2_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune2_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune2_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune2_epoch10
#
# finetuning model_dyn...
# optimizing model_dyn, lr =  0.0001
# Epoch 0/9
# ----------
# train rec loss: 3.2412e-01 dyn loss: 4.1677e-04 dyn loss(bg): 4.1677e-04 loss_R: 2.7788e-01 loss_I: 3.3073e-01
# val rec loss: 4.5956e-01 dyn loss: 5.0448e-04 dyn loss(bg): 5.0448e-04 loss_R: 3.6641e-01 loss_I: 4.7286e-01
#
# Epoch 1/9
# ----------
# train rec loss: 3.1790e-01 dyn loss: 3.8711e-04 dyn loss(bg): 3.8711e-04 loss_R: 2.7257e-01 loss_I: 3.2438e-01
# val rec loss: 4.5423e-01 dyn loss: 5.0044e-04 dyn loss(bg): 5.0044e-04 loss_R: 3.6253e-01 loss_I: 4.6733e-01
#
# Epoch 2/9
# ----------
# train rec loss: 3.1414e-01 dyn loss: 3.8371e-04 dyn loss(bg): 3.8371e-04 loss_R: 2.6938e-01 loss_I: 3.2054e-01
# val rec loss: 4.5199e-01 dyn loss: 5.0162e-04 dyn loss(bg): 5.0162e-04 loss_R: 3.6081e-01 loss_I: 4.6501e-01
#
# Epoch 3/9
# ----------
# train rec loss: 3.1230e-01 dyn loss: 3.8403e-04 dyn loss(bg): 3.8403e-04 loss_R: 2.6791e-01 loss_I: 3.1864e-01
# val rec loss: 4.5120e-01 dyn loss: 5.0270e-04 dyn loss(bg): 5.0270e-04 loss_R: 3.6085e-01 loss_I: 4.6411e-01
#
# Epoch 4/9
# ----------
# train rec loss: 3.1013e-01 dyn loss: 3.8321e-04 dyn loss(bg): 3.8321e-04 loss_R: 2.6616e-01 loss_I: 3.1641e-01
# val rec loss: 4.4921e-01 dyn loss: 5.0239e-04 dyn loss(bg): 5.0239e-04 loss_R: 3.5888e-01 loss_I: 4.6212e-01
#
# Epoch 5/9
# ----------
# train rec loss: 3.0841e-01 dyn loss: 3.8256e-04 dyn loss(bg): 3.8256e-04 loss_R: 2.6472e-01 loss_I: 3.1465e-01
# val rec loss: 4.4843e-01 dyn loss: 4.9934e-04 dyn loss(bg): 4.9934e-04 loss_R: 3.5833e-01 loss_I: 4.6130e-01
#
# Epoch 6/9
# ----------
# train rec loss: 3.0721e-01 dyn loss: 3.8292e-04 dyn loss(bg): 3.8292e-04 loss_R: 2.6381e-01 loss_I: 3.1341e-01
# val rec loss: 4.4652e-01 dyn loss: 5.0502e-04 dyn loss(bg): 5.0502e-04 loss_R: 3.5693e-01 loss_I: 4.5932e-01
#
# Epoch 7/9
# ----------
# train rec loss: 3.0585e-01 dyn loss: 3.8285e-04 dyn loss(bg): 3.8285e-04 loss_R: 2.6275e-01 loss_I: 3.1201e-01
# val rec loss: 4.4669e-01 dyn loss: 5.0198e-04 dyn loss(bg): 5.0198e-04 loss_R: 3.5708e-01 loss_I: 4.5950e-01
#
# Epoch 8/9
# ----------
# train rec loss: 3.0464e-01 dyn loss: 3.8475e-04 dyn loss(bg): 3.8475e-04 loss_R: 2.6171e-01 loss_I: 3.1077e-01
# val rec loss: 4.4558e-01 dyn loss: 5.1226e-04 dyn loss(bg): 5.1226e-04 loss_R: 3.5668e-01 loss_I: 4.5828e-01
#
# Epoch 9/9
# ----------
# train rec loss: 3.0390e-01 dyn loss: 3.8618e-04 dyn loss(bg): 3.8618e-04 loss_R: 2.6116e-01 loss_I: 3.1000e-01
# val rec loss: 4.4675e-01 dyn loss: 5.0884e-04 dyn loss(bg): 5.0884e-04 loss_R: 3.5800e-01 loss_I: 4.5943e-01
#
# Training complete in 6m 4s
# Best val reconstruction loss: 4.455788e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune3_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune3_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune3_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune3_epoch10
#
# step:  2
# finetuning model_sup...
# optimizing model_sup, lr =  0.0001
# optimizing model_head, lr =  0
# Epoch 0/9
# ----------
# train rec loss: 2.8757e-01 dyn loss: 2.8507e-04 dyn loss(bg): 2.8507e-04 loss_R: 2.5284e-01 loss_I: 2.9253e-01
# val rec loss: 4.2095e-01 dyn loss: 3.6388e-04 dyn loss(bg): 3.6388e-04 loss_R: 3.4380e-01 loss_I: 4.3197e-01
#
# Epoch 1/9
# ----------
# train rec loss: 2.8062e-01 dyn loss: 2.7643e-04 dyn loss(bg): 2.7643e-04 loss_R: 2.4599e-01 loss_I: 2.8557e-01
# val rec loss: 4.1825e-01 dyn loss: 3.5832e-04 dyn loss(bg): 3.5832e-04 loss_R: 3.4146e-01 loss_I: 4.2922e-01
#
# Epoch 2/9
# ----------
# train rec loss: 2.7989e-01 dyn loss: 2.7392e-04 dyn loss(bg): 2.7392e-04 loss_R: 2.4509e-01 loss_I: 2.8486e-01
# val rec loss: 4.1767e-01 dyn loss: 3.5861e-04 dyn loss(bg): 3.5861e-04 loss_R: 3.4059e-01 loss_I: 4.2869e-01
#
# Epoch 3/9
# ----------
# train rec loss: 2.7928e-01 dyn loss: 2.7336e-04 dyn loss(bg): 2.7336e-04 loss_R: 2.4436e-01 loss_I: 2.8427e-01
# val rec loss: 4.1657e-01 dyn loss: 3.5566e-04 dyn loss(bg): 3.5566e-04 loss_R: 3.3916e-01 loss_I: 4.2763e-01
#
# Epoch 4/9
# ----------
# train rec loss: 2.7901e-01 dyn loss: 2.7327e-04 dyn loss(bg): 2.7327e-04 loss_R: 2.4404e-01 loss_I: 2.8401e-01
# val rec loss: 4.1696e-01 dyn loss: 3.6100e-04 dyn loss(bg): 3.6100e-04 loss_R: 3.3953e-01 loss_I: 4.2802e-01
#
# Epoch 5/9
# ----------
# train rec loss: 2.7840e-01 dyn loss: 2.7258e-04 dyn loss(bg): 2.7258e-04 loss_R: 2.4339e-01 loss_I: 2.8340e-01
# val rec loss: 4.1639e-01 dyn loss: 3.5675e-04 dyn loss(bg): 3.5675e-04 loss_R: 3.3920e-01 loss_I: 4.2742e-01
#
# Epoch 6/9
# ----------
# train rec loss: 2.7846e-01 dyn loss: 2.7207e-04 dyn loss(bg): 2.7207e-04 loss_R: 2.4336e-01 loss_I: 2.8347e-01
# val rec loss: 4.1598e-01 dyn loss: 3.5431e-04 dyn loss(bg): 3.5431e-04 loss_R: 3.3866e-01 loss_I: 4.2703e-01
#
# Epoch 7/9
# ----------
# train rec loss: 2.7824e-01 dyn loss: 2.7146e-04 dyn loss(bg): 2.7146e-04 loss_R: 2.4315e-01 loss_I: 2.8325e-01
# val rec loss: 4.1680e-01 dyn loss: 3.5971e-04 dyn loss(bg): 3.5971e-04 loss_R: 3.3992e-01 loss_I: 4.2778e-01
#
# Epoch 8/9
# ----------
# train rec loss: 2.7814e-01 dyn loss: 2.7145e-04 dyn loss(bg): 2.7145e-04 loss_R: 2.4302e-01 loss_I: 2.8315e-01
# val rec loss: 4.1569e-01 dyn loss: 3.5575e-04 dyn loss(bg): 3.5575e-04 loss_R: 3.3841e-01 loss_I: 4.2672e-01
#
# Epoch 9/9
# ----------
# train rec loss: 2.7756e-01 dyn loss: 2.7197e-04 dyn loss(bg): 2.7197e-04 loss_R: 2.4247e-01 loss_I: 2.8257e-01
# val rec loss: 4.1537e-01 dyn loss: 3.5874e-04 dyn loss(bg): 3.5874e-04 loss_R: 3.3828e-01 loss_I: 4.2638e-01
#
# Training complete in 7m 10s
# Best val reconstruction loss: 4.153669e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune4_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune4_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune4_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune4_epoch10
#
# finetuning model_dyn...
# optimizing model_dyn, lr =  0.0001
# Epoch 0/9
# ----------
# train rec loss: 2.8428e-01 dyn loss: 2.8770e-04 dyn loss(bg): 2.8770e-04 loss_R: 2.4852e-01 loss_I: 2.8938e-01
# val rec loss: 4.1228e-01 dyn loss: 3.3485e-04 dyn loss(bg): 3.3485e-04 loss_R: 3.3486e-01 loss_I: 4.2334e-01
#
# Epoch 1/9
# ----------
# train rec loss: 2.7320e-01 dyn loss: 2.4493e-04 dyn loss(bg): 2.4493e-04 loss_R: 2.3832e-01 loss_I: 2.7818e-01
# val rec loss: 4.1133e-01 dyn loss: 3.2800e-04 dyn loss(bg): 3.2800e-04 loss_R: 3.3477e-01 loss_I: 4.2227e-01
#
# Epoch 2/9
# ----------
# train rec loss: 2.7254e-01 dyn loss: 2.4476e-04 dyn loss(bg): 2.4476e-04 loss_R: 2.3783e-01 loss_I: 2.7750e-01
# val rec loss: 4.1141e-01 dyn loss: 3.3172e-04 dyn loss(bg): 3.3172e-04 loss_R: 3.3443e-01 loss_I: 4.2241e-01
#
# Epoch 3/9
# ----------
# train rec loss: 2.7045e-01 dyn loss: 2.4584e-04 dyn loss(bg): 2.4584e-04 loss_R: 2.3593e-01 loss_I: 2.7538e-01
# val rec loss: 4.0895e-01 dyn loss: 3.3074e-04 dyn loss(bg): 3.3074e-04 loss_R: 3.3288e-01 loss_I: 4.1982e-01
#
# Epoch 4/9
# ----------
# train rec loss: 2.6940e-01 dyn loss: 2.4539e-04 dyn loss(bg): 2.4539e-04 loss_R: 2.3509e-01 loss_I: 2.7431e-01
# val rec loss: 4.0978e-01 dyn loss: 3.2933e-04 dyn loss(bg): 3.2933e-04 loss_R: 3.3402e-01 loss_I: 4.2060e-01
#
# Epoch 5/9
# ----------
# train rec loss: 2.6798e-01 dyn loss: 2.4515e-04 dyn loss(bg): 2.4515e-04 loss_R: 2.3382e-01 loss_I: 2.7286e-01
# val rec loss: 4.0949e-01 dyn loss: 3.2993e-04 dyn loss(bg): 3.2993e-04 loss_R: 3.3355e-01 loss_I: 4.2034e-01
#
# Epoch 6/9
# ----------
# train rec loss: 2.6783e-01 dyn loss: 2.4735e-04 dyn loss(bg): 2.4735e-04 loss_R: 2.3384e-01 loss_I: 2.7269e-01
# val rec loss: 4.1069e-01 dyn loss: 3.4352e-04 dyn loss(bg): 3.4352e-04 loss_R: 3.3498e-01 loss_I: 4.2150e-01
#
# Epoch 7/9
# ----------
# train rec loss: 2.6651e-01 dyn loss: 2.4854e-04 dyn loss(bg): 2.4854e-04 loss_R: 2.3268e-01 loss_I: 2.7134e-01
# val rec loss: 4.0822e-01 dyn loss: 3.3712e-04 dyn loss(bg): 3.3712e-04 loss_R: 3.3301e-01 loss_I: 4.1896e-01
#
# Epoch 8/9
# ----------
# train rec loss: 2.6581e-01 dyn loss: 2.4633e-04 dyn loss(bg): 2.4633e-04 loss_R: 2.3210e-01 loss_I: 2.7062e-01
# val rec loss: 4.0920e-01 dyn loss: 3.3370e-04 dyn loss(bg): 3.3370e-04 loss_R: 3.3315e-01 loss_I: 4.2006e-01
#
# Epoch 9/9
# ----------
# train rec loss: 2.6555e-01 dyn loss: 2.4683e-04 dyn loss(bg): 2.4683e-04 loss_R: 2.3198e-01 loss_I: 2.7035e-01
# val rec loss: 4.0578e-01 dyn loss: 3.3123e-04 dyn loss(bg): 3.3123e-04 loss_R: 3.3001e-01 loss_I: 4.1660e-01
#
# Training complete in 8m 39s
# Best val reconstruction loss: 4.057773e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune5_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune5_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune5_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune5_epoch10
#
# step:  3
# finetuning model_sup...
# optimizing model_sup, lr =  0.0001
# optimizing model_head, lr =  0
# Epoch 0/9
# ----------
# train rec loss: 2.6041e-01 dyn loss: 2.2516e-04 dyn loss(bg): 2.2516e-04 loss_R: 2.3124e-01 loss_I: 2.6458e-01
# val rec loss: 3.9113e-01 dyn loss: 2.8988e-04 dyn loss(bg): 2.8988e-04 loss_R: 3.2316e-01 loss_I: 4.0084e-01
#
# Epoch 1/9
# ----------
# train rec loss: 2.4862e-01 dyn loss: 2.2070e-04 dyn loss(bg): 2.2070e-04 loss_R: 2.1988e-01 loss_I: 2.5273e-01
# val rec loss: 3.9108e-01 dyn loss: 2.9522e-04 dyn loss(bg): 2.9522e-04 loss_R: 3.2306e-01 loss_I: 4.0080e-01
#
# Epoch 2/9
# ----------
# train rec loss: 2.4797e-01 dyn loss: 2.2145e-04 dyn loss(bg): 2.2145e-04 loss_R: 2.1926e-01 loss_I: 2.5207e-01
# val rec loss: 3.9066e-01 dyn loss: 2.9295e-04 dyn loss(bg): 2.9295e-04 loss_R: 3.2323e-01 loss_I: 4.0029e-01
#
# Epoch 3/9
# ----------
# train rec loss: 2.4791e-01 dyn loss: 2.2168e-04 dyn loss(bg): 2.2168e-04 loss_R: 2.1919e-01 loss_I: 2.5201e-01
# val rec loss: 3.9065e-01 dyn loss: 2.9571e-04 dyn loss(bg): 2.9571e-04 loss_R: 3.2299e-01 loss_I: 4.0031e-01
#
# Epoch 4/9
# ----------
# train rec loss: 2.4770e-01 dyn loss: 2.2163e-04 dyn loss(bg): 2.2163e-04 loss_R: 2.1898e-01 loss_I: 2.5181e-01
# val rec loss: 3.9034e-01 dyn loss: 2.8703e-04 dyn loss(bg): 2.8703e-04 loss_R: 3.2251e-01 loss_I: 4.0003e-01
#
# Epoch 5/9
# ----------
# train rec loss: 2.4763e-01 dyn loss: 2.2082e-04 dyn loss(bg): 2.2082e-04 loss_R: 2.1891e-01 loss_I: 2.5174e-01
# val rec loss: 3.9021e-01 dyn loss: 2.9720e-04 dyn loss(bg): 2.9720e-04 loss_R: 3.2271e-01 loss_I: 3.9985e-01
#
# Epoch 6/9
# ----------
# train rec loss: 2.4745e-01 dyn loss: 2.2167e-04 dyn loss(bg): 2.2167e-04 loss_R: 2.1878e-01 loss_I: 2.5155e-01
# val rec loss: 3.9175e-01 dyn loss: 2.9407e-04 dyn loss(bg): 2.9407e-04 loss_R: 3.2313e-01 loss_I: 4.0156e-01
#
# Epoch 7/9
# ----------
# train rec loss: 2.4745e-01 dyn loss: 2.2165e-04 dyn loss(bg): 2.2165e-04 loss_R: 2.1873e-01 loss_I: 2.5155e-01
# val rec loss: 3.8976e-01 dyn loss: 2.9077e-04 dyn loss(bg): 2.9077e-04 loss_R: 3.2180e-01 loss_I: 3.9947e-01
#
# Epoch 8/9
# ----------
# train rec loss: 2.4771e-01 dyn loss: 2.2120e-04 dyn loss(bg): 2.2120e-04 loss_R: 2.1893e-01 loss_I: 2.5182e-01
# val rec loss: 3.9254e-01 dyn loss: 2.9435e-04 dyn loss(bg): 2.9435e-04 loss_R: 3.2480e-01 loss_I: 4.0221e-01
#
# Epoch 9/9
# ----------
# train rec loss: 2.4709e-01 dyn loss: 2.2230e-04 dyn loss(bg): 2.2230e-04 loss_R: 2.1840e-01 loss_I: 2.5118e-01
# val rec loss: 3.8952e-01 dyn loss: 2.9124e-04 dyn loss(bg): 2.9124e-04 loss_R: 3.2166e-01 loss_I: 3.9921e-01
#
# Training complete in 9m 14s
# Best val reconstruction loss: 3.895165e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune6_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune6_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune6_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune6_epoch10
#
# finetuning model_dyn...
# optimizing model_dyn, lr =  0.0001
# Epoch 0/9
# ----------
# train rec loss: 2.8633e-01 dyn loss: 2.5296e-04 dyn loss(bg): 2.5296e-04 loss_R: 2.5440e-01 loss_I: 2.9089e-01
# val rec loss: 3.8952e-01 dyn loss: 2.7268e-04 dyn loss(bg): 2.7268e-04 loss_R: 3.2025e-01 loss_I: 3.9942e-01
#
# Epoch 1/9
# ----------
# train rec loss: 2.4638e-01 dyn loss: 2.0316e-04 dyn loss(bg): 2.0316e-04 loss_R: 2.1706e-01 loss_I: 2.5057e-01
# val rec loss: 3.8782e-01 dyn loss: 2.7478e-04 dyn loss(bg): 2.7478e-04 loss_R: 3.1952e-01 loss_I: 3.9758e-01
#
# Epoch 2/9
# ----------
# train rec loss: 2.4584e-01 dyn loss: 2.0588e-04 dyn loss(bg): 2.0588e-04 loss_R: 2.1677e-01 loss_I: 2.4999e-01
# val rec loss: 3.8736e-01 dyn loss: 2.7706e-04 dyn loss(bg): 2.7706e-04 loss_R: 3.1953e-01 loss_I: 3.9705e-01
#
# Epoch 3/9
# ----------
# train rec loss: 2.4479e-01 dyn loss: 2.0739e-04 dyn loss(bg): 2.0739e-04 loss_R: 2.1588e-01 loss_I: 2.4892e-01
# val rec loss: 3.8878e-01 dyn loss: 2.7658e-04 dyn loss(bg): 2.7658e-04 loss_R: 3.2053e-01 loss_I: 3.9853e-01
#
# Epoch 4/9
# ----------
# train rec loss: 2.4458e-01 dyn loss: 2.0834e-04 dyn loss(bg): 2.0834e-04 loss_R: 2.1568e-01 loss_I: 2.4871e-01
# val rec loss: 3.8789e-01 dyn loss: 2.7780e-04 dyn loss(bg): 2.7780e-04 loss_R: 3.1938e-01 loss_I: 3.9768e-01
#
# Epoch 5/9
# ----------
# train rec loss: 2.4317e-01 dyn loss: 2.0825e-04 dyn loss(bg): 2.0825e-04 loss_R: 2.1438e-01 loss_I: 2.4728e-01
# val rec loss: 3.8522e-01 dyn loss: 2.8075e-04 dyn loss(bg): 2.8075e-04 loss_R: 3.1755e-01 loss_I: 3.9489e-01
#
# Epoch 6/9
# ----------
# train rec loss: 2.4275e-01 dyn loss: 2.0923e-04 dyn loss(bg): 2.0923e-04 loss_R: 2.1405e-01 loss_I: 2.4685e-01
# val rec loss: 3.8554e-01 dyn loss: 2.8561e-04 dyn loss(bg): 2.8561e-04 loss_R: 3.1811e-01 loss_I: 3.9517e-01
#
# Epoch 7/9
# ----------
# train rec loss: 2.4302e-01 dyn loss: 2.0905e-04 dyn loss(bg): 2.0905e-04 loss_R: 2.1432e-01 loss_I: 2.4711e-01
# val rec loss: 3.8666e-01 dyn loss: 2.8447e-04 dyn loss(bg): 2.8447e-04 loss_R: 3.1899e-01 loss_I: 3.9633e-01
#
# Epoch 8/9
# ----------
# train rec loss: 2.4182e-01 dyn loss: 2.1086e-04 dyn loss(bg): 2.1086e-04 loss_R: 2.1330e-01 loss_I: 2.4590e-01
# val rec loss: 3.8909e-01 dyn loss: 2.8037e-04 dyn loss(bg): 2.8037e-04 loss_R: 3.2118e-01 loss_I: 3.9879e-01
#
# Epoch 9/9
# ----------
# train rec loss: 2.4111e-01 dyn loss: 2.0945e-04 dyn loss(bg): 2.0945e-04 loss_R: 2.1270e-01 loss_I: 2.4517e-01
# val rec loss: 3.8901e-01 dyn loss: 2.8042e-04 dyn loss(bg): 2.8042e-04 loss_R: 3.2124e-01 loss_I: 3.9869e-01
#
# Training complete in 11m 24s
# Best val reconstruction loss: 3.852195e-01
# saving model_head at ckpts/20220828_bgerr0.0/finetune7_head_epoch10
# saving model_sup at ckpts/20220828_bgerr0.0/finetune7_sup_epoch10
# saving model_dyn at ckpts/20220828_bgerr0.0/finetune7_dyn_epoch10
# saving loss at train_loss/20220828_bgerr0.0/finetune7_epoch10
